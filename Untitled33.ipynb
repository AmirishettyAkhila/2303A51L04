# %% [markdown]
# <a href="https://colab.research.google.com/github/AmirishettyAkhila/2303A51L04/blob/main/Untitled33.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Retry creating the presentation with enhanced visuals using color gradients and shapes

# Load the presentation object
prs = Presentation()

# Function to add gradient background
def add_gradient_background(slide, color1, color2):
    background = slide.background
    fill = background.fill
    fill.gradient()
    stop_1, stop_2 = fill.gradient_stops[0], fill.gradient_stops[1]
    stop_1.position = 0.0
    stop_1.color.rgb = RGBColor(*color1)
    stop_2.position = 1.0
    stop_2.color.rgb = RGBColor(*color2)

# Slide 1: Title Slide with Gradient Background
slide_1 = prs.slides.add_slide(prs.slide_layouts[5])
add_gradient_background(slide_1, (0, 51, 102), (0, 153, 153))
title = slide_1.shapes.title
title.text = "Piezoelectric Tiles: Harnessing Kinetic Energy for Sustainable Power"
title.text_frame.paragraphs[0].font.size = Pt(40)
title.text_frame.paragraphs[0].font.bold = True
title.text_frame.paragraphs[0].font.color.rgb = RGBColor(255, 255, 255)
subtitle = slide_1.shapes.add_textbox(Inches(1), Inches(4.5), Inches(8), Inches(2))
subtitle_text_frame = subtitle.text_frame
subtitle_text_frame.text = "Innovative Flooring Solutions for Energy Generation"
p = subtitle_text_frame.add_paragraph()
p.text = "Your Name"
p = subtitle_text_frame.add_paragraph()
p.text = "Date"
for para in subtitle_text_frame.paragraphs:
    para.font.size = Pt(28)
    para.font.color.rgb = RGBColor(255, 255, 255)

# Slide 2: Introduction with Gradient Background
slide_2 = prs.slides.add_slide(prs.slide_layouts[5])
add_gradient_background(slide_2, (102, 153, 255), (0, 76, 153))
title = slide_2.shapes.add_textbox(Inches(0.5), Inches(0.5), Inches(8), Inches(1.5))
title_text_frame = title.text_frame
title_text_frame.text = "Introduction"
title_text_frame.paragraphs[0].font.size = Pt(32)
title_text_frame.paragraphs[0].font.bold = True
title_text_frame.paragraphs[0].font.color.rgb = RGBColor(255, 255, 255)

content = slide_2.shapes.add_textbox(Inches(0.5), Inches(2), Inches(9), Inches(5))
content_text_frame = content.text_frame
content_text_frame.text = "What are Piezoelectric Tiles?"
p = content_text_frame.add_paragraph()
p.text = "• Piezoelectric tiles convert mechanical stress (footsteps) into electrical energy."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)

# Slide 3: The Science Behind Piezoelectricity with Gradient Background
slide_3 = prs.slides.add_slide(prs.slide_layouts[5])
add_gradient_background(slide_3, (153, 102, 255), (102, 0, 204))
title = slide_3.shapes.add_textbox(Inches(0.5), Inches(0.5), Inches(8), Inches(1.5))
title_text_frame = title.text_frame
title_text_frame.text = "The Science Behind Piezoelectricity"
title_text_frame.paragraphs[0].font.size = Pt(32)
title_text_frame.paragraphs[0].font.bold = True
title_text_frame.paragraphs[0].font.color.rgb = RGBColor(255, 255, 255)

content = slide_3.shapes.add_textbox(Inches(0.5), Inches(2), Inches(9), Inches(5))
content_text_frame = content.text_frame
content_text_frame.text = "Piezoelectric Effect:"
p = content_text_frame.add_paragraph()
p.text = "• Principle: Mechanical stress generates electrical charge."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)
p = content_text_frame.add_paragraph()
p.text = "• Common materials: Quartz, certain ceramics."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)

# Slide 4: Applications of Piezoelectric Tiles
slide_4 = prs.slides.add_slide(prs.slide_layouts[5])
add_gradient_background(slide_4, (255, 102, 102), (204, 0, 0))
title = slide_4.shapes.add_textbox(Inches(0.5), Inches(0.5), Inches(8), Inches(1.5))
title_text_frame = title.text_frame
title_text_frame.text = "Applications of Piezoelectric Tiles"
title_text_frame.paragraphs[0].font.size = Pt(32)
title_text_frame.paragraphs[0].font.bold = True
title_text_frame.paragraphs[0].font.color.rgb = RGBColor(255, 255, 255)

content = slide_4.shapes.add_textbox(Inches(0.5), Inches(2), Inches(9), Inches(5))
content_text_frame = content.text_frame
content_text_frame.text = "High-Traffic Areas:"
p = content_text_frame.add_paragraph()
p.text = "• Examples: Shopping malls, train stations, airports."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)
p = content_text_frame.add_paragraph()
p.text = "• Potential energy output in such environments."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)
p = content_text_frame.add_paragraph()
p.text = "Powering Low-Energy Devices:"
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)

# Slide 5: Environmental and Economic Benefits
slide_5 = prs.slides.add_slide(prs.slide_layouts[5])
add_gradient_background(slide_5, (102, 255, 102), (0, 153, 0))
title = slide_5.shapes.add_textbox(Inches(0.5), Inches(0.5), Inches(8), Inches(1.5))
title_text_frame = title.text_frame
title_text_frame.text = "Environmental and Economic Benefits"
title_text_frame.paragraphs[0].font.size = Pt(32)
title_text_frame.paragraphs[0].font.bold = True
title_text_frame.paragraphs[0].font.color.rgb = RGBColor(255, 255, 255)

content = slide_5.shapes.add_textbox(Inches(0.5), Inches(2), Inches(9), Inches(5))
content_text_frame = content.text_frame
content_text_frame.text = "Sustainability:"
p = content_text_frame.add_paragraph()
p.text = "• Reducing reliance on conventional energy sources."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)
p = content_text_frame.add_paragraph()
p.text = "• Lowering carbon footprint."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)
p = content_text_frame.add_paragraph()
p.text = "Cost Efficiency:"
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)

# Slide 6: Case Studies and Real-World Examples
slide_6 = prs.slides.add_slide(prs.slide_layouts[5])
add_gradient_background(slide_6, (255, 178, 102), (255, 102, 0))
title = slide_6.shapes.add_textbox(Inches(0.5), Inches(0.5), Inches(8), Inches(1.5))
title_text_frame = title.text_frame
title_text_frame.text = "Case Studies and Real-World Examples"
title_text_frame.paragraphs[0].font.size = Pt(32)
title_text_frame.paragraphs[0].font.bold = True
title_text_frame.paragraphs[0].font.color.rgb = RGBColor(255, 255, 255)

content = slide_6.shapes.add_textbox(Inches(0.5), Inches(2), Inches(9), Inches(5))
content_text_frame = content.text_frame
content_text_frame.text = "Existing Implementations:"
p = content_text_frame.add_paragraph()
p.text = "• Highlight places where piezoelectric tiles are in use."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)
p = content_text_frame.add_paragraph()
p.text = "• Discuss the outcomes and impact."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)

# Slide 7: Challenges and Considerations
slide_7 = prs.slides.add_slide(prs.slide_layouts[5])
add_gradient_background(slide_7, (102, 178,
# Out:
#   File "<ipython-input-1-9592f5999713>", line 161
#     add_gradient_background(slide_7, (102, 178,
#                                                 ^
# SyntaxError: incomplete input

# %%
from pptx import Presentation
from pptx.util import Inches, Pt
from pptx.dml.color import RGBColor

# Create a new presentation object
prs = Presentation()

# Function to add gradient background
def add_gradient_background(slide, color1, color2):
    background = slide.background
    fill = background.fill
    fill.gradient()
    stop_1, stop_2 = fill.gradient_stops[0], fill.gradient_stops[1]
    stop_1.position = 0.0
    stop_1.color.rgb = RGBColor(*color1)
    stop_2.position = 1.0
    stop_2.color.rgb = RGBColor(*color2)

# Slide 1: Title Slide with Gradient Background
slide_1 = prs.slides.add_slide(prs.slide_layouts[5])
add_gradient_background(slide_1, (0, 51, 102), (0, 153, 153))
title = slide_1.shapes.title
title.text = "Piezoelectric Tiles: Harnessing Kinetic Energy for Sustainable Power"
title.text_frame.paragraphs[0].font.size = Pt(40)
title.text_frame.paragraphs[0].font.bold = True
title.text_frame.paragraphs[0].font.color.rgb = RGBColor(255, 255, 255)
subtitle = slide_1.shapes.add_textbox(Inches(1), Inches(4.5), Inches(8), Inches(2))
subtitle_text_frame = subtitle.text_frame
subtitle_text_frame.text = "Innovative Flooring Solutions for Energy Generation"
p = subtitle_text_frame.add_paragraph()
p.text = "Your Name"
p = subtitle_text_frame.add_paragraph()
p.text = "Date"
for para in subtitle_text_frame.paragraphs:
    para.font.size = Pt(28)
    para.font.color.rgb = RGBColor(255, 255, 255)

# Slide 2: Introduction with Gradient Background
slide_2 = prs.slides.add_slide(prs.slide_layouts[5])
add_gradient_background(slide_2, (102, 153, 255), (0, 76, 153))
title = slide_2.shapes.add_textbox(Inches(0.5), Inches(0.5), Inches(8), Inches(1.5))
title_text_frame = title.text_frame
title_text_frame.text = "Introduction"
title_text_frame.paragraphs[0].font.size = Pt(32)
title_text_frame.paragraphs[0].font.bold = True
title_text_frame.paragraphs[0].font.color.rgb = RGBColor(255, 255, 255)

content = slide_2.shapes.add_textbox(Inches(0.5), Inches(2), Inches(9), Inches(5))
content_text_frame = content.text_frame
content_text_frame.text = "What are Piezoelectric Tiles?"
p = content_text_frame.add_paragraph()
p.text = "• Piezoelectric tiles convert mechanical stress (footsteps) into electrical energy."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)

# Slide 3: The Science Behind Piezoelectricity with Gradient Background
slide_3 = prs.slides.add_slide(prs.slide_layouts[5])
add_gradient_background(slide_3, (153, 102, 255), (102, 0, 204))
title = slide_3.shapes.add_textbox(Inches(0.5), Inches(0.5), Inches(8), Inches(1.5))
title_text_frame = title.text_frame
title_text_frame.text = "The Science Behind Piezoelectricity"
title_text_frame.paragraphs[0].font.size = Pt(32)
title_text_frame.paragraphs[0].font.bold = True
title_text_frame.paragraphs[0].font.color.rgb = RGBColor(255, 255, 255)

content = slide_3.shapes.add_textbox(Inches(0.5), Inches(2), Inches(9), Inches(5))
content_text_frame = content.text_frame
content_text_frame.text = "Piezoelectric Effect:"
p = content_text_frame.add_paragraph()
p.text = "• Principle: Mechanical stress generates electrical charge."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)
p = content_text_frame.add_paragraph()
p.text = "• Common materials: Quartz, certain ceramics."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)

# Slide 4: Applications of Piezoelectric Tiles
slide_4 = prs.slides.add_slide(prs.slide_layouts[5])
add_gradient_background(slide_4, (255, 102, 102), (204, 0, 0))
title = slide_4.shapes.add_textbox(Inches(0.5), Inches(0.5), Inches(8), Inches(1.5))
title_text_frame = title.text_frame
title_text_frame.text = "Applications of Piezoelectric Tiles"
title_text_frame.paragraphs[0].font.size = Pt(32)
title_text_frame.paragraphs[0].font.bold = True
title_text_frame.paragraphs[0].font.color.rgb = RGBColor(255, 255, 255)

content = slide_4.shapes.add_textbox(Inches(0.5), Inches(2), Inches(9), Inches(5))
content_text_frame = content.text_frame
content_text_frame.text = "High-Traffic Areas:"
p = content_text_frame.add_paragraph()
p.text = "• Examples: Shopping malls, train stations, airports."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)
p = content_text_frame.add_paragraph()
p.text = "• Potential energy output in such environments."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)
p = content_text_frame.add_paragraph()
p.text = "Powering Low-Energy Devices:"
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)

# Slide 5: Environmental and Economic Benefits
slide_5 = prs.slides.add_slide(prs.slide_layouts[5])
add_gradient_background(slide_5, (102, 255, 102), (0, 153, 0))
title = slide_5.shapes.add_textbox(Inches(0.5), Inches(0.5), Inches(8), Inches(1.5))
title_text_frame = title.text_frame
title_text_frame.text = "Environmental and Economic Benefits"
title_text_frame.paragraphs[0].font.size = Pt(32)
title_text_frame.paragraphs[0].font.bold = True
title_text_frame.paragraphs[0].font.color.rgb = RGBColor(255, 255, 255)

content = slide_5.shapes.add_textbox(Inches(0.5), Inches(2), Inches(9), Inches(5))
content_text_frame = content.text_frame
content_text_frame.text = "Sustainability:"
p = content_text_frame.add_paragraph()
p.text = "• Reducing reliance on conventional energy sources."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)
p = content_text_frame.add_paragraph()
p.text = "• Lowering carbon footprint."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)
p = content_text_frame.add_paragraph()
p.text = "Cost Efficiency:"
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)

# Slide 6: Case Studies and Real-World Examples
slide_6 = prs.slides.add_slide(prs.slide_layouts[5])
add_gradient_background(slide_6, (255, 178, 102), (255, 102, 0))
title = slide_6.shapes.add_textbox(Inches(0.5), Inches(0.5), Inches(8), Inches(1.5))
title_text_frame = title.text_frame
title_text_frame.text = "Case Studies and Real-World Examples"
title_text_frame.paragraphs[0].font.size = Pt(32)
title_text_frame.paragraphs[0].font.bold = True
title_text_frame.paragraphs[0].font.color.rgb = RGBColor(255, 255, 255)

content = slide_6.shapes.add_textbox(Inches(0.5), Inches(2), Inches(9), Inches(5))
content_text_frame = content.text_frame
content_text_frame.text = "Existing Implementations:"
p = content_text_frame.add_paragraph()
p.text = "• Highlight places where piezoelectric tiles are in use."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)
p = content_text_frame.add_paragraph()
p.text = "• Discuss the outcomes and impact."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)

slide_7 = prs.slides.add_slide(prs.slide_layouts[5])
add_gradient_background(slide_7, (102, 178, 255), (0, 102, 204))
title = slide_7.shapes.add_textbox(Inches(0.5), Inches(0.5), Inches(8), Inches(1.5))
title_text_frame = title.text_frame
title_text_frame.text = "Challenges and Considerations"
title_text_frame.paragraphs[0].font.size = Pt(32)
title_text_frame.paragraphs[0].font.bold = True
title_text_frame.paragraphs[0].font.color.rgb = RGBColor(255, 255, 255)

content = slide_7.shapes.add_textbox(Inches(0.5), Inches(2), Inches(9), Inches(5))
content_text_frame = content.text_frame
content_text_frame.text = "Challenges:"
p = content_text_frame.add_paragraph()
p.text = "• Initial costs and installation complexity."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)
p = content_text_frame.add_paragraph()
p.text = "• Maintenance and durability."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)

# Slide 8: Conclusion with Gradient Background
slide_8 = prs.slides.add_slide(prs.slide_layouts[5])
add_gradient_background(slide_8, (255, 255, 102), (255, 204, 0))
title = slide_8.shapes.add_textbox(Inches(0.5), Inches(0.5), Inches(8), Inches(1.5))
title_text_frame = title.text_frame
title_text_frame.text = "Conclusion"
title_text_frame.paragraphs[0].font.size = Pt(32)
title_text_frame.paragraphs[0].font.bold = True
title_text_frame.paragraphs[0].font.color.rgb = RGBColor(255, 255, 255)

content = slide_8.shapes.add_textbox(Inches(0.5), Inches(2), Inches(9), Inches(5))
content_text_frame = content.text_frame
content_text_frame.text = "Piezoelectric Tiles:"
p = content_text_frame.add_paragraph()
p.text = "• A promising sustainable energy solution for the future."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)
p = content_text_frame.add_paragraph()
p.text = "• Potential to significantly impact energy efficiency in urban spaces."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)

# Save the presentation
prs.save('Piezoelectric_Tiles_Presentation.pptx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-09c5f929022f> in <cell line: 1>()
# ----> 1 from pptx import Presentation
#       2 from pptx.util import Inches, Pt
#       3 from pptx.dml.color import RGBColor
#       4
#       5 # Create a new presentation object
#
# ModuleNotFoundError: No module named 'pptx'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Install the python-pptx package
# !pip install python-pptx

# Now, run the code to create the presentation
from pptx import Presentation
from pptx.util import Inches, Pt
from pptx.dml.color import RGBColor

# Create a new presentation object
prs = Presentation()

# Function to add gradient background
def add_gradient_background(slide, color1, color2):
    background = slide.background
    fill = background.fill
    fill.gradient()
    stop_1, stop_2 = fill.gradient_stops[0], fill.gradient_stops[1]
    stop_1.position = 0.0
    stop_1.color.rgb = RGBColor(*color1)
    stop_2.position = 1.0
    stop_2.color.rgb = RGBColor(*color2)

# Slide 1: Title Slide with Gradient Background
slide_1 = prs.slides.add_slide(prs.slide_layouts[5])
add_gradient_background(slide_1, (0, 51, 102), (0, 153, 153))
title = slide_1.shapes.title
title.text = "Piezoelectric Tiles: Harnessing Kinetic Energy for Sustainable Power"
title.text_frame.paragraphs[0].font.size = Pt(40)
title.text_frame.paragraphs[0].font.bold = True
title.text_frame.paragraphs[0].font.color.rgb = RGBColor(255, 255, 255)
subtitle = slide_1.shapes.add_textbox(Inches(1), Inches(4.5), Inches(8), Inches(2))
subtitle_text_frame = subtitle.text_frame
subtitle_text_frame.text = "Innovative Flooring Solutions for Energy Generation"
p = subtitle_text_frame.add_paragraph()
p.text = "Your Name"
p = subtitle_text_frame.add_paragraph()
p.text = "Date"
for para in subtitle_text_frame.paragraphs:
    para.font.size = Pt(28)
    para.font.color.rgb = RGBColor(255, 255, 255)

# Slide 2: Introduction with Gradient Background
slide_2 = prs.slides.add_slide(prs.slide_layouts[5])
add_gradient_background(slide_2, (102, 153, 255), (0, 76, 153))
title = slide_2.shapes.add_textbox(Inches(0.5), Inches(0.5), Inches(8), Inches(1.5))
title_text_frame = title.text_frame
title_text_frame.text = "Introduction"
title_text_frame.paragraphs[0].font.size = Pt(32)
title_text_frame.paragraphs[0].font.bold = True
title_text_frame.paragraphs[0].font.color.rgb = RGBColor(255, 255, 255)

content = slide_2.shapes.add_textbox(Inches(0.5), Inches(2), Inches(9), Inches(5))
content_text_frame = content.text_frame
content_text_frame.text = "What are Piezoelectric Tiles?"
p = content_text_frame.add_paragraph()
p.text = "• Piezoelectric tiles convert mechanical stress (footsteps) into electrical energy."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)

# Slide 3: The Science Behind Piezoelectricity with Gradient Background
slide_3 = prs.slides.add_slide(prs.slide_layouts[5])
add_gradient_background(slide_3, (153, 102, 255), (102, 0, 204))
title = slide_3.shapes.add_textbox(Inches(0.5), Inches(0.5), Inches(8), Inches(1.5))
title_text_frame = title.text_frame
title_text_frame.text = "The Science Behind Piezoelectricity"
title_text_frame.paragraphs[0].font.size = Pt(32)
title_text_frame.paragraphs[0].font.bold = True
title_text_frame.paragraphs[0].font.color.rgb = RGBColor(255, 255, 255)

content = slide_3.shapes.add_textbox(Inches(0.5), Inches(2), Inches(9), Inches(5))
content_text_frame = content.text_frame
content_text_frame.text = "Piezoelectric Effect:"
p = content_text_frame.add_paragraph()
p.text = "• Principle: Mechanical stress generates electrical charge."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)
p = content_text_frame.add_paragraph()
p.text = "• Common materials: Quartz, certain ceramics."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)

# Slide 4: Applications of Piezoelectric Tiles
slide_4 = prs.slides.add_slide(prs.slide_layouts[5])
add_gradient_background(slide_4, (255, 102, 102), (204, 0, 0))
title = slide_4.shapes.add_textbox(Inches(0.5), Inches(0.5), Inches(8), Inches(1.5))
title_text_frame = title.text_frame
title_text_frame.text = "Applications of Piezoelectric Tiles"
title_text_frame.paragraphs[0].font.size = Pt(32)
title_text_frame.paragraphs[0].font.bold = True
title_text_frame.paragraphs[0].font.color.rgb = RGBColor(255, 255, 255)

content = slide_4.shapes.add_textbox(Inches(0.5), Inches(2), Inches(9), Inches(5))
content_text_frame = content.text_frame
content_text_frame.text = "High-Traffic Areas:"
p = content_text_frame.add_paragraph()
p.text = "• Examples: Shopping malls, train stations, airports."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)
p = content_text_frame.add_paragraph()
p.text = "• Potential energy output in such environments."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)
p = content_text_frame.add_paragraph()
p.text = "Powering Low-Energy Devices:"
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)

# Slide 5: Environmental and Economic Benefits
slide_5 = prs.slides.add_slide(prs.slide_layouts[5])
add_gradient_background(slide_5, (102, 255, 102), (0, 153, 0))
title = slide_5.shapes.add_textbox(Inches(0.5), Inches(0.5), Inches(8), Inches(1.5))
title_text_frame = title.text_frame
title_text_frame.text = "Environmental and Economic Benefits"
title_text_frame.paragraphs[0].font.size = Pt(32)
title_text_frame.paragraphs[0].font.bold = True
title_text_frame.paragraphs[0].font.color.rgb = RGBColor(255, 255, 255)

content = slide_5.shapes.add_textbox(Inches(0.5), Inches(2), Inches(9), Inches(5))
content_text_frame = content.text_frame
content_text_frame.text = "Sustainability:"
p = content_text_frame.add_paragraph()
p.text = "• Reducing reliance on conventional energy sources."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)
p = content_text_frame.add_paragraph()
p.text = "• Lowering carbon footprint."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)
p = content_text_frame.add_paragraph()
p.text = "Cost Efficiency:"
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)

# Slide 6: Case Studies and Real-World Examples
slide_6 = prs.slides.add_slide(prs.slide_layouts[5])
add_gradient_background(slide_6, (255, 178, 102), (255, 102, 0))
title = slide_6.shapes.add_textbox(Inches(0.5), Inches(0.5), Inches(8), Inches(1.5))
title_text_frame = title.text_frame
title_text_frame.text = "Case Studies and Real-World Examples"
title_text_frame.paragraphs[0].font.size = Pt(32)
title_text_frame.paragraphs[0].font.bold = True
title_text_frame.paragraphs[0].font.color.rgb = RGBColor(255, 255, 255)

content = slide_6.shapes.add_textbox(Inches(0.5), Inches(2), Inches(9), Inches(5))
content_text_frame = content.text_frame
content_text_frame.text = "Existing Implementations:"
p = content_text_frame.add_paragraph()
p.text = "• Highlight places where piezoelectric tiles are in use."
p.level = 1
p.font.size = Pt(24)
p.font.color.rgb = RGBColor(255, 255, 255)
p = content_text_frame.add_paragraph()
p.text = "• Discuss the outcomes and impact."
p.level = 1
p.font.size = Pt(24)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 10.0 MB/s eta 0:00:00
# ...
